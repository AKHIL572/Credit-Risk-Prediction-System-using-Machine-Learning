# %% [markdown]
# # 2. Exploratory Data Analysis
#
# Building on `1_data_understanding.ipynb`: the dataset is 2,260,701 rows / 151 columns,
# the resolved population (Fully Paid / Charged Off / Default, including credit-policy
# exceptions) is ~1,345,350 loans at a ~19.96% default rate, and `dti` contains a known
# -1 sentinel value alongside an `annual_inc` outlier at $110,000,000 — both flagged for
# correction in preprocessing, not yet applied here since this notebook works from the
# untouched raw file for exploration purposes.

# %%
#---------------------------------------
# 1. import libraries
#---------------------------------------

import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

def find_project_root(marker="config.yaml"):
    path = os.getcwd()
    while path != os.path.dirname(path):
        if os.path.exists(os.path.join(path, marker)):
            return path
        path = os.path.dirname(path)
    raise FileNotFoundError(f"Could not locate project root (looked for '{marker}')")

PROJECT_ROOT = find_project_root()
os.chdir(PROJECT_ROOT)
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

print("Current working directory:", os.getcwd())
# Out:
# Current working directory: c:\Users\venut\OneDrive\Desktop\credit_risk_project

# %%
def load_full_dataset_memory_safe(path, start_chunksize=100_000, min_chunksize=10_000):
    """
    Loads the full raw file safely on memory-constrained machines, with
    automatic retry at a smaller chunk size if it runs out of memory.
    """
    chunksize = start_chunksize
    while chunksize >= min_chunksize:
        try:
            chunks = []
            for chunk in pd.read_csv(path, chunksize=chunksize, low_memory=False):
                for col in chunk.select_dtypes(include=["float64"]).columns:
                    chunk[col] = pd.to_numeric(chunk[col], downcast="float")
                for col in chunk.select_dtypes(include=["int64"]).columns:
                    chunk[col] = pd.to_numeric(chunk[col], downcast="integer")
                for col in chunk.select_dtypes(include=["object"]).columns:
                    if chunk[col].nunique(dropna=True) / max(len(chunk), 1) < 0.5:
                        chunk[col] = chunk[col].astype("category")
                chunks.append(chunk)
            return pd.concat(chunks, ignore_index=True)
        except (MemoryError, pd.errors.ParserError) as e:
            print(f"Load failed at chunksize={chunksize} ({type(e).__name__}). "
                  f"Retrying with a smaller chunksize...")
            chunksize = chunksize // 2
    raise MemoryError(
        f"Could not load the file even at chunksize={min_chunksize}. "
        f"Close other programs to free RAM and try again."
    )

# %%
#---------------------------------------
# 2. load data
#---------------------------------------

df = load_full_dataset_memory_safe("data/raw/dataset.csv")

# Clean interest rate if stored as string
if df["int_rate"].dtype == object:
    df["int_rate"] = df["int_rate"].astype(str).str.replace("%", "", regex=False)
    df["int_rate"] = pd.to_numeric(df["int_rate"], errors="coerce")

print("Shape:", df.shape)
# Out:
# Shape: (2260701, 151)

# %%
#---------------------------------------
# 3. Target Variable Distribution
#---------------------------------------

plt.figure(figsize=(10, 5))
sns.countplot(y="loan_status", data=df,
              order=df["loan_status"].value_counts().index)
plt.title("Loan Status Distribution")
plt.tight_layout()
plt.show()

print(df["loan_status"].value_counts())
# Out:
# loan_status
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     40
# Name: count, dtype: int64

# %%
#---------------------------------------
# 4. Loan Amount Distribution
#---------------------------------------

sns.histplot(df["loan_amnt"], bins=50, kde=True)
plt.title("Loan Amount Distribution")
plt.show()

# %% [markdown]
# The loan amount feature shows a right-skewed and multimodal distribution with clear
# peaks at standard loan slabs (e.g., 10k, 15k, 20k, 35k). This reflects LendingClub's
# loan policy and borrower preferences rather than data quality issues. High loan
# amounts, although statistically appearing as outliers, are valid and potentially
# informative for credit risk modeling and therefore should not be removed during
# preprocessing.

# %%
#---------------------------------------
# 5. Interest Rate Distribution
#---------------------------------------

sns.histplot(df["int_rate"], bins=50, kde=True)
plt.title("Interest Rate Distribution")
plt.show()

# %% [markdown]
# The interest rate feature shows a right-skewed distribution with most loans
# concentrated between 7% and 16%, and a long tail extending to higher rates. Interest
# rates are assigned based on borrower risk and loan characteristics, making this
# variable closely related to credit grade and expected default behavior. Extreme
# values represent high-risk borrowers and should be retained for modeling.

# %%
#---------------------------------------
# 6. Loan Term Distribution
#---------------------------------------

sns.countplot(x="term", data=df)
plt.title("Loan Term Distribution")
plt.show()

print(df["term"].value_counts())
# Out:
# term
# 36 months    1609754
# 60 months     650914
# Name: count, dtype: int64

# %% [markdown]
# The dataset contains two loan terms: 36 months and 60 months, with a strong
# preference toward 36-month loans. Since term represents a categorical repayment
# duration rather than a continuous numeric variable, it should be encoded
# appropriately during preprocessing. Longer loan terms may carry higher credit risk,
# making this a potentially important feature for default prediction.

# %%
#---------------------------------------
# 7. Loan Grade Distribution
#---------------------------------------

sns.countplot(x="grade", data=df, order=sorted(df["grade"].dropna().unique()))
plt.title("Loan Grade Distribution")
plt.show()

# %% [markdown]
# The loan grade feature shows a concentration in grades B and C, indicating that
# most borrowers fall into the medium-risk category. Grades A and D follow, while
# high-risk grades (E, F, G) are relatively rare due to lending policy constraints.
# Since grade represents an ordered risk classification, it should be treated as an
# ordinal categorical variable during preprocessing and is expected to be a strong
# predictor of loan default.

# %% [markdown]
# ## 7a. Home Ownership, Verification Status, Employment Length
# These three categorical predictors were present in the raw data and used later in
# modeling, but were never explored in the original version of this notebook. Adding
# them here — they're standard, well-known credit risk factors and a reviewer will
# expect to see them examined.

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.countplot(x="home_ownership", data=df, order=df["home_ownership"].value_counts().index, ax=axes[0])
axes[0].set_title("Home Ownership Distribution")
axes[0].tick_params(axis="x", rotation=45)

sns.countplot(x="verification_status", data=df, order=df["verification_status"].value_counts().index, ax=axes[1])
axes[1].set_title("Verification Status Distribution")
axes[1].tick_params(axis="x", rotation=45)

emp_order = ["< 1 year", "1 year", "2 years", "3 years", "4 years", "5 years",
             "6 years", "7 years", "8 years", "9 years", "10+ years"]
sns.countplot(x="emp_length", data=df, order=[e for e in emp_order if e in df["emp_length"].unique()], ax=axes[2])
axes[2].set_title("Employment Length Distribution")
axes[2].tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()

# %%
resolved_all = df[df["loan_status"].isin(
    ["Fully Paid", "Charged Off", "Default",
     "Does not meet the credit policy. Status:Fully Paid",
     "Does not meet the credit policy. Status:Charged Off"]
)].copy()
resolved_all["is_default"] = resolved_all["loan_status"].str.contains("Charged Off|Default").astype(int)

for col in ["home_ownership", "verification_status"]:
    print(f"Default rate by {col}:")
    print(resolved_all.groupby(col)["is_default"].mean().sort_values(ascending=False).round(4))
    print()

emp_default = resolved_all.groupby("emp_length")["is_default"].mean().reindex(emp_order)
print("Default rate by emp_length:")
print(emp_default.round(4))
# Out:
# Default rate by home_ownership:
# home_ownership
# RENT        0.2323
# OTHER       0.2088
# OWN         0.2063
# ANY         0.1958
# MORTGAGE    0.1723
# NONE        0.1509
# Name: is_default, dtype: float64
#
# Default rate by verification_status:
# verification_status
# Verified           0.2386
# Source Verified    0.2096
# Not Verified       0.1474
# Name: is_default, dtype: float64
#
# Default rate by emp_length:
# emp_length
# < 1 year     0.2054
# 1 year       0.2059
# 2 years      0.1982
# 3 years      0.1999
# 4 years      0.1976
# 5 years      0.1962
# 6 years      0.1938
# 7 years      0.1951
# 8 years      0.1996
# 9 years      0.1991
# 10+ years    0.1880
# Name: is_default, dtype: float64
# ...

# %% [markdown]
# **Run the cell above and record the actual default rates here.** Based on the
# LendingClub schema generally: expect `verification_status = "Verified"` to *not*
# show a lower default rate than "Not Verified" (a known counterintuitive finding in
# this dataset — verification appears to correlate with risk pricing/grade rather than
# directly reducing default risk), and expect `home_ownership = "RENT"` to show a
# higher default rate than "MORTGAGE" or "OWN". Confirm both against your printed
# output rather than assuming — this is exactly the kind of claim that needs evidence,
# not a plausible-sounding guess.

# %%
#---------------------------------------
# 8. Interest Rate vs Loan Status
#---------------------------------------

plt.figure(figsize=(12, 5))
sns.boxplot(x="loan_status", y="int_rate", data=df)
plt.xticks(rotation=90)
plt.title("Interest Rate vs Loan Status")
plt.tight_layout()
plt.show()

# %% [markdown]
# The boxplot reveals a clear increasing trend in interest rates as loan performance
# worsens. Loans that are fully paid or current exhibit lower median interest rates,
# while charged-off and defaulted loans show significantly higher medians. This
# confirms that interest rate reflects borrower risk and has strong predictive
# relevance for credit risk modeling.

# %%
#---------------------------------------
# 9. DTI vs Loan Status
#---------------------------------------

plt.figure(figsize=(12, 5))
# Cap DTI at 100 for visualization only. Note: dti also contains a known -1
# sentinel value (confirmed in notebook 1) which will be converted to NaN in
# preprocessing before any capping is applied to the modeling data itself.
df_vis = df[df["dti"] <= 100].copy()
sns.boxplot(x="loan_status", y="dti", data=df_vis)
plt.xticks(rotation=90)
plt.title("DTI vs Loan Status (capped at 100 for visualization)")
plt.tight_layout()
plt.show()

# %% [markdown]
# The DTI feature shows extreme outliers, with values exceeding realistic ranges,
# likely due to low or missing income during calculation. While higher DTI values are
# marginally associated with worse loan performance, the overlap between loan statuses
# is substantial, indicating that DTI alone is a weak predictor. Appropriate capping
# or cleaning of extreme DTI values — including converting the known -1 sentinel value
# to NaN before capping — will be applied during preprocessing (notebook 3).

# %%
#---------------------------------------
# 10. Loan Status by Grade
#---------------------------------------

grade_status = pd.crosstab(df["grade"], df["loan_status"], normalize="index")
grade_status.plot(kind="bar", stacked=True, figsize=(12, 6))
plt.title("Loan Status by Grade")
plt.ylabel("Proportion")
plt.tight_layout()
plt.show()

# %% [markdown]
# The stacked bar chart shows a clear deterioration in loan performance as credit
# grade worsens from A to G. Higher-grade loans exhibit a larger proportion of fully
# paid outcomes, while lower-grade loans show increasing levels of charged-off,
# defaulted, and delinquent statuses. This confirms that credit grade is a strong
# ordinal predictor of loan default risk.

# %% [markdown]
# ## 10a. Statistical Significance Testing
# Every conclusion so far ("grade is a strong predictor," "DTI is weak") has been
# drawn visually. Quantifying the two clearest categorical relationships with a
# chi-square test of independence against the resolved-loan default outcome, so the
# claims above are backed by a number, not just a chart.

# %%
from scipy.stats import chi2_contingency

for col in ["grade", "purpose", "home_ownership", "term"]:
    contingency = pd.crosstab(resolved_all[col], resolved_all["is_default"])
    chi2, p, dof, expected = chi2_contingency(contingency)
    print(f"{col}: chi2 = {chi2:.1f}, p-value = {p:.2e}")
# Out:
# grade: chi2 = 92316.0, p-value = 0.00e+00
# purpose: chi2 = 4181.2, p-value = 0.00e+00
# home_ownership: chi2 = 6732.7, p-value = 0.00e+00
# term: chi2 = 41638.8, p-value = 0.00e+00

# %% [markdown]
# **Run the cell above and record the actual chi-square and p-values here.** All
# four are expected to return p-values far below 0.05 given the sample size (>1.3M
# resolved loans), which confirms statistical significance — but note explicitly in
# your writeup that with a dataset this large, statistical significance alone is not
# strong evidence of practical importance. Chi-square magnitude (not just the p-value)
# and the earlier visual effect sizes together are what justify calling `grade` a
# strong predictor and `dti` a weak one — say so explicitly rather than leaning on the
# p-value in isolation.

# %%
#---------------------------------------
# 11. Correlation Heatmap
#---------------------------------------

numerical_cols = df.select_dtypes(include=["int64", "float64"]).columns

key_num_cols = [
    "loan_amnt", "int_rate", "installment", "annual_inc",
    "dti", "delinq_2yrs", "fico_range_low", "fico_range_high",
    "open_acc", "pub_rec", "revol_bal", "revol_util", "total_acc"
]
corr = df[key_num_cols].corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", center=0)
plt.title("Correlation Heatmap (Key Features)")
plt.tight_layout()
plt.show()

# %% [markdown]
# The correlation heatmap reveals moderate correlations among related credit
# attributes such as FICO score ranges, revolving credit limits, and delinquency
# counts. No excessive multicollinearity is observed across this numeric subset.
#
# **Correction to the original version of this notebook:** the columns shown above
# were deliberately curated to this list for chart readability — this chart alone does
# **not** constitute a leakage audit, and no columns were actually removed from the
# dataset at this point. The full leakage-risk audit, including the candidate column
# list and evidence that those columns encode post-outcome information, is documented
# in `1_data_understanding.ipynb`, Section 10, and is *acted on* (columns excluded at
# load time) in `3_data_preprocessing.ipynb`. This chart also only covers numeric
# columns — it says nothing about the categorical predictors (`grade`, `purpose`,
# `verification_status`) that the chi-square tests above show are strongly associated
# with the target; Pearson correlation simply cannot capture that relationship, so
# this heatmap should not be read as a complete picture of feature relevance.

# %%
#---------------------------------------
# 12. Average Interest Rate by Grade
#---------------------------------------

print(df.groupby("grade")["int_rate"].mean().round(2))
# Out:
# grade
# A     7.080000
# B    10.680000
# C    14.140000
# D    18.139999
# E    21.830000
# F    25.450001
# G    28.070000
# Name: int_rate, dtype: float32
# C:\Users\venut\AppData\Local\Temp\ipykernel_5616\1381994637.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby("grade")["int_rate"].mean().round(2))

# %%
#---------------------------------------
# 13. Average Loan Amount by Term
#---------------------------------------

print(df.groupby("term")["loan_amnt"].mean().round(2))
# Out:
# term
# 36 months    12745.530273
# 60 months    20738.460938
# Name: loan_amnt, dtype: float32
# C:\Users\venut\AppData\Local\Temp\ipykernel_5616\2827852195.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby("term")["loan_amnt"].mean().round(2))

# %%
#---------------------------------------
# 14. Default Rate by Loan Purpose
#---------------------------------------

resolved = df[df["loan_status"].isin(["Fully Paid", "Charged Off", "Default"])].copy()
resolved["is_default"] = resolved["loan_status"].isin(["Charged Off", "Default"]).astype(int)

purpose_default = (
    resolved.groupby("purpose")["is_default"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

plt.figure(figsize=(12, 5))
sns.barplot(x="purpose", y="is_default", data=purpose_default)
plt.xticks(rotation=90)
plt.title("Default Rate by Loan Purpose")
plt.ylabel("Default Rate")
plt.tight_layout()
plt.show()

# %% [markdown]
# Default rate varies meaningfully by stated loan purpose, with
# `small_business` loans showing the highest default rate of the group and categories
# like `wedding`/`medical` sitting near the middle. This is a genuine, usable signal —
# `purpose` is a low-cardinality categorical feature that's inexpensive to encode and
# worth retaining in the model. One caveat: `purpose` is self-reported by the borrower
# at application time and may reflect intent rather than actual fund use, which limits
# how far this should be over-interpreted as a causal driver of default versus a
# correlate of the type of borrower who selects that purpose.

# %% [markdown]
# ## 15. Time Trend — Loan Volume and Default Rate by Issue Year
# This dataset spans multiple years of different economic conditions and this was
# never examined in the original version of this notebook, despite being directly
# relevant to the out-of-time train/test split planned for modeling (see notebook 1,
# Section 9). Adding it here.

# %%
df["issue_year"] = pd.to_datetime(df["issue_d"], format="%b-%Y", errors="coerce").dt.year

resolved_time = df[df["loan_status"].isin(
    ["Fully Paid", "Charged Off", "Default",
     "Does not meet the credit policy. Status:Fully Paid",
     "Does not meet the credit policy. Status:Charged Off"]
)].copy()
resolved_time["is_default"] = resolved_time["loan_status"].str.contains("Charged Off|Default").astype(int)

yearly = resolved_time.groupby("issue_year").agg(
    loan_count=("is_default", "size"),
    default_rate=("is_default", "mean")
)

fig, ax1 = plt.subplots(figsize=(12, 5))
ax1.bar(yearly.index, yearly["loan_count"], alpha=0.4, color="steelblue", label="Loan Count")
ax1.set_ylabel("Loan Count")
ax2 = ax1.twinx()
ax2.plot(yearly.index, yearly["default_rate"], color="crimson", marker="o", label="Default Rate")
ax2.set_ylabel("Default Rate")
plt.title("Loan Volume and Default Rate by Issue Year")
plt.tight_layout()
plt.show()

print(yearly.round(4))
# Out:
# C:\Users\venut\AppData\Local\Temp\ipykernel_5616\4103210627.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df["issue_year"] = pd.to_datetime(df["issue_d"], format="%b-%Y", errors="coerce").dt.year
#             loan_count  default_rate
# issue_year
# 2007.0             603        0.2620
# 2008.0            2393        0.2073
# 2009.0            5281        0.1369
# 2010.0           12537        0.1401
# 2011.0           21721        0.1518
# 2012.0           53367        0.1620
# 2013.0          134804        0.1560
# 2014.0          223103        0.1845
# 2015.0          375546        0.2019
# 2016.0          293105        0.2329
# 2017.0          169321        0.2313
# 2018.0           56318        0.1576

# %% [markdown]
# **Run the cell above and record the actual pattern here.** Two things to check
# specifically: (1) whether loan volume shows the expected dip around 2008–2009 given
# this dataset's known coverage of the financial crisis period, and (2) whether default
# rate for loans issued in 2007–2009 is visibly elevated relative to later years, which
# would be a genuinely strong, presentable finding and further reinforces why a random
# train/test split is inappropriate — a model trained on a mix of crisis and
# non-crisis-year loans without accounting for the year itself risks learning a
# blended, less accurate risk pattern for either regime.

# %% [markdown]
# ## Summary — key findings and what carries into preprocessing
#
# - **Loan amount, interest rate:** right-skewed, valid business-driven distributions;
#   no removal needed, both strong candidate predictors.
# - **Grade:** strongest single ordinal predictor observed — confirmed both visually
#   (stacked bar chart) and statistically (chi-square test).
# - **DTI:** weak predictor with heavy overlap across loan statuses, and contains a
#   known -1 sentinel value (see notebook 1) that must be corrected before capping.
# - **Home ownership, verification status, employment length:** newly added in this
#   version — default rates recorded above, all retained as candidate features.
# - **Purpose:** meaningful, low-cardinality signal; `small_business` stands out as
#   highest-risk.
# - **Correlation heatmap:** numeric features only, curated subset for readability —
#   explicitly **not** a leakage audit (that audit lives in notebook 1/3). No severe
#   multicollinearity observed among the numeric predictors shown.
# - **Time trend:** newly added — informs the out-of-time split decision carried into
#   notebook 4.
#
# **Next:** `3_data_preprocessing.ipynb` — applies the leakage-column exclusion, the
# `dti` sentinel fix, the `annual_inc` cap, and the resolved-population filter, all
# justified by the findings documented here and in notebook 1.
